# %%
import pandas as pd    #import pandas library
import numpy as np     #import numpy library

# %%
data=pd.read_excel("C:/Users/ping6/Downloads/Telco-Customer-Churn.xlsx")   #read data from excel file
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.head(5)  #read the first 5 rows
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # S-1

# %% [markdown]
# # Customers own their connection based on gender and citizenship

# %%
d1=data[data["Churn"]=="No"];d1  #take data of customers own their connection.
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# ...          ...     ...            ...     ...        ...     ...
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
d1["gender"].value_counts()  #returs number of male and female customers.
# Out:
# Male      2625
# Female    2549
# Name: gender, dtype: int64

# %%
d1["SeniorCitizen"].value_counts() #returns number of customer based on citizenship
# Out:
# 0    4508
# 1     666
# Name: SeniorCitizen, dtype: int64

# %% [markdown]
# # S-2

# %% [markdown]
# # Customers left  their service base on gender and citizenship

# %%
d2=data[data["Churn"]=="Yes"];d2  # take data of customers left their connection.
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %%
d2["gender"].value_counts()   #return number customer left the service based on gender
# Out:
# Female    939
# Male      930
# Name: gender, dtype: int64

# %%
d2["SeniorCitizen"].value_counts()  #return number of customer left their service based on cityzenship
# Out:
# 0    1393
# 1     476
# Name: SeniorCitizen, dtype: int64

# %% [markdown]
# # S-3

# %% [markdown]
# # 3.Preference of  payment method based on churn and contract

# %%
data["PaymentMethod"].unique()   # finding unique value in the column name PaymentMethod
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
data["Contract"].unique()  # finding unique value in the column name Contract
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Preference of payment method based on customers own their service in percentage

d1["PaymentMethod"].value_counts(normalize=True)*100
# Out:
# Mailed check                 25.202938
# Electronic check             25.009664
# Credit card (automatic)      24.932354
# Bank transfer (automatic)    24.855044
# Name: PaymentMethod, dtype: float64

# %%
# Preference of payment method based on customers left their service in percentage

d2["PaymentMethod"].value_counts(normalize=True)*100
# Out:
# Electronic check             57.303371
# Mailed check                 16.479401
# Bank transfer (automatic)    13.804173
# Credit card (automatic)      12.413055
# Name: PaymentMethod, dtype: float64

# %%
d3 = data[data['Contract'] == 'Month-to-month']   #Defining a dataframe of column "Contract" having value "Month-to-Month"
d4 = data[data['Contract'] == 'One year']         #Defining a dataframe of column "Contract" having value "One year"
d5 = data[data['Contract'] == 'Two year']         #Defining a dataframe of column "Contract" having value "Two year"

# %%
d3["PaymentMethod"].value_counts(normalize=True)*100  # Preference of payment method based on customers having contract "Month-to-Month"in percentage
# Out:
# Electronic check             47.741935
# Mailed check                 23.045161
# Bank transfer (automatic)    15.200000
# Credit card (automatic)      14.012903
# Name: PaymentMethod, dtype: float64

# %%
d4["PaymentMethod"].value_counts(normalize=True)*100  # Preference of payment method based on customers having contract "One year"in percentage
# Out:
# Credit card (automatic)      27.019688
# Bank transfer (automatic)    26.544467
# Electronic check             23.557366
# Mailed check                 22.878479
# Name: PaymentMethod, dtype: float64

# %%
d5["PaymentMethod"].value_counts(normalize=True)*100   #Preference of payment method based on customers having contract "Two year"in percentage
# Out:
# Credit card (automatic)      34.277286
# Bank transfer (automatic)    33.274336
# Mailed check                 22.536873
# Electronic check              9.911504
# Name: PaymentMethod, dtype: float64

# %% [markdown]
# # S-4

# %% [markdown]
# # 4.Internet service preference by gender based on churn status.

# %%
data["InternetService"].unique()  #finding unique values of the column InternetService
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
# Internet service preference by Male customers own their service in percentage
d6 = d1[data["gender"] == "Male"]
d6['InternetService'].value_counts(normalize = True)*100
# Out:
# <ipython-input-37-3c71c245b0a6>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   d6 = d1[data["gender"] == "Male"]
# DSL            37.828571
# Fiber optic    34.666667
# No             27.504762
# Name: InternetService, dtype: float64

# %%
# Internet service preference by Male customers left their service in percentage
d7 = d2[data["gender"] == "Male"]
d7['InternetService'].value_counts(normalize = True)*100
# Out:
# <ipython-input-63-17c249632518>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   d7 = d2[data["gender"] == "Male"]
# Fiber optic    68.064516
# DSL            25.806452
# No              6.129032
# Name: InternetService, dtype: float64

# %%
# Internet service preference by Female customers own their service in percentage

d8= d1[data["gender"] == "Female"]
d8['InternetService'].value_counts(normalize = True)*100
# Out:
# <ipython-input-64-40fc362a416c>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   d8= d1[data["gender"] == "Female"]
# DSL            38.014908
# Fiber optic    34.876422
# No             27.108670
# Name: InternetService, dtype: float64

# %%
# Internet service preference by Female customers left their service in percentage

d9 = d2[data["gender"] == "Female"]
d9['InternetService'].value_counts(normalize = True)*100
# Out:
# <ipython-input-43-94ffb3d8504d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   d9 = d2[data["gender"] == "Female"]
# Fiber optic    70.713525
# DSL            23.322684
# No              5.963791
# Name: InternetService, dtype: float64

# %% [markdown]
# # S-5
#
# # 5. Explain the descriptive statistics of “TotalCharges” based on Gender,Contract, and  Payment Method

# %%
data.columns #column names
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#the descriptive statistics of “TotalCharges” based on Male Customers
x1=data[data["gender"]=="Male"]
x1["TotalCharges"].describe()
# Out:
# count    3555.000000
# mean     2291.680667
# std      2273.095299
# min        18.800000
# 25%       399.275000
# 50%      1406.000000
# 75%      3778.100000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
#the descriptive statistics of “TotalCharges” based on Female Customers

x2=data[data["gender"]=="Female"]
x2["TotalCharges"].describe()
# Out:
# count    3488.000000
# mean     2289.338308
# std      2276.695359
# min        18.850000
# 25%       403.300000
# 50%      1389.050000
# 75%      3834.062500
# max      8672.450000
# Name: TotalCharges, dtype: float64

# %%
#the descriptive statistics of “TotalCharges” based on Customers having contract of one year
x3=data[data["Contract"]=="One year"]
x3["TotalCharges"].describe()
# Out:
# count    1473.000000
# mean     3038.377461
# std      2233.477741
# min        18.800000
# 25%       989.450000
# 50%      2658.400000
# 75%      4860.350000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
#the descriptive statistics of “TotalCharges” based on Customers having contract of month-to-month
x4=data[data["Contract"]=="Month-to-month"]
x4["TotalCharges"].describe()
# Out:
# count    3875.000000
# mean     1369.254581
# std      1613.879008
# min        18.850000
# 25%       160.100000
# 50%       679.550000
# 75%      2066.500000
# max      8061.500000
# Name: TotalCharges, dtype: float64

# %%
#the descriptive statistics of “TotalCharges” based on Customers having contract of Two year
x5=data[data["Contract"]=="Two year"]
x5["TotalCharges"].describe()
# Out:
# count    1695.000000
# mean     3746.752383
# std      2582.454154
# min        20.350000
# 25%      1280.125000
# 50%      3638.250000
# 75%      6044.300000
# max      8672.450000
# Name: TotalCharges, dtype: float64

# %%
#the descriptive statistics of “TotalCharges” based on Customers having mailed check Payment Method 
x6 = data[data['PaymentMethod'] == 'Mailed check']
x6['TotalCharges'].describe()
# Out:
# count    1612.000000
# mean     1083.236973
# std      1509.101844
# min        18.800000
# 25%       116.937500
# 50%       473.675000
# 75%      1316.000000
# max      8476.500000
# Name: TotalCharges, dtype: float64

# %%
#the descriptive statistics of “TotalCharges” based on Customers having Credit card(automatic) Payment Method
x7 = data[data['PaymentMethod'] == 'Credit card (automatic)']
x7['TotalCharges'].describe()
# Out:
# count    1522.000000
# mean     3074.920894
# std      2410.536742
# min        19.300000
# 25%       989.400000
# 50%      2454.175000
# 75%      5016.550000
# max      8670.100000
# Name: TotalCharges, dtype: float64

# %%
#the descriptive statistics of “TotalCharges” based on Customers having Electronic check Payment Method
x8 = data[data['PaymentMethod'] == 'Electronic check']
x8['TotalCharges'].describe()
# Out:
# count    2365.000000
# mean     2090.868182
# std      2155.435320
# min        18.850000
# 25%       308.050000
# 50%      1253.900000
# 75%      3340.550000
# max      8564.750000
# Name: TotalCharges, dtype: float64

# %%
#the descriptive statistics of “TotalCharges” based on Customers having Bank transfer Payment Method
x9 = data[data['PaymentMethod'] == 'Bank transfer (automatic)']
x9['TotalCharges'].describe()
# Out:
# count    1544.000000
# mean     3083.566023
# std      2360.362773
# min        19.250000
# 25%      1052.387500
# 50%      2479.500000
# 75%      4948.337500
# max      8684.800000
# Name: TotalCharges, dtype: float64
